# %%
# To run the workflow, execute the command below

# %%
! snakemake --cores 1
# Out:
# Assuming unrestricted shared filesystem usage.
# host: Bushras-MacBook-Pro.local
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# make_plots                     1
# merge_zip                      1
# select_clean_rat               1
# select_clean_restaurant        1
# summary_and_findings           1
# unzip_rat                      1
# unzip_restaurant               1
# total                          8
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Tue Dec  9 19:48:37 2025]
# localrule unzip_rat:
#     input: data/clean/Rat-cleaned.zip
#     output: data/clean/Rat-cleaned_in.csv
#     jobid: 2
#     reason: Missing output files: data/clean/Rat-cleaned_in.csv; Updated input files: data/clean/Rat-cleaned.zip
# ...
